# %%
# !git clone https://github.com/adsp-polito/2025-P1-Topic-detection.git
# Out:
# Cloning into '2025-P1-Topic-detection'...
# remote: Enumerating objects: 218, done.
# remote: Counting objects: 100% (218/218), done.
# remote: Compressing objects: 100% (184/184), done.
# remote: Total 218 (delta 90), reused 113 (delta 29), pack-reused 0 (from 0)
# Receiving objects: 100% (218/218), 26.29 MiB | 23.23 MiB/s, done.
# Resolving deltas: 100% (90/90), done.

# %%
# %cd /content/2025-P1-Topic-detection
# Out:
# /content/2025-P1-Topic-detection

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 20.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 49.5 MB/s eta 0:00:00
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=a88f63668a755e3eac900c157e469adbe8cea705e34e2537a60ab88904a35e58
#   Stored in directory: /root/.cache/pip/wheels/c1/67/88/e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# ...

# %%
import wandb
wandb.login()

# %%
rm -rf out

# %%
# !python main.py
# Out:
# --> [Config] Loaded configuration from config.yaml
# 2025-12-07 17:47:42.192922: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765129662.212739    4676 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765129662.218753    4676 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765129662.233956    4676 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import shutil
from google.colab import files

folder_path = '/content/2025-P1-Topic-detection/out'
output_filename = 'out'

shutil.make_archive(output_filename, 'zip', folder_path)

files.download(output_filename + '.zip')
